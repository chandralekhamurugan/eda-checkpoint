# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:https://www.kaggle.com/datasets/shivan118/big-mart-sales-prediction-datasets
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %% [markdown]
# # Business Issue:
#
# Reading through the post, it’s about sales prediction for Big Mart Outlets. Using this dataset, the data analyst can identify the properties of products and outlets that are key factors in increasing the sales, and to build a predictive model that can forecast the sales of each product at a particular outlet.

# %% [markdown]
# # Import

# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %% [markdown]
# # Create New DataFrames

# %%
train_data=pd.read_csv('train.csv')
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Dataframe Info

# %%
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# None

# %% [markdown]
# # Show the first 20 rows

# %%
train_data.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %% [markdown]
# # Groupby "Item_Identifier" for the first five column

# %%
train_data.groupby("Item_Identifier").first(5)
# Out:
#                  Item_Weight  Item_Visibility  Item_MRP  \
# Item_Identifier
# DRA12                 11.600         0.041178  140.3154
# DRA24                 19.350         0.040154  164.6868
# DRA59                  8.270         0.127928  184.8924
# DRB01                  7.390         0.082367  187.7530
# DRB13                  6.115         0.007084  191.1530
# ...                      ...              ...       ...
# NCZ30                  6.590         0.043828  121.4098
# NCZ41                 19.850         0.064368  126.1704
# NCZ42                 10.500         0.000000  238.3248
# NCZ53                  9.600         0.024577  186.6214
# NCZ54                 14.650         0.000000  161.5552
#
#                  Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Identifier
# DRA12                                 2007          2552.6772
# DRA24                                 2007          1146.5076
# DRA59                                 1997          4442.2176
# ...

# %% [markdown]
# # Check how many rows and columns are present

# %%
train_data.shape
# Out:
# (8523, 12)

# %% [markdown]
# # Get column names

# %%
train_data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # Find Null Values
# Item_Weight = 1463, Item_Visibility = 228, Outlet_Size = 2410 contains Null Values

# %%
train_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# # Getting categorical columns

# %%
categorial_cols = train_data.select_dtypes(exclude='number').columns.to_list()

print('Categorical Columns: ', categorial_cols)
# Out:
# Categorical Columns:  ['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %% [markdown]
# # Exploring Categorical columns

# %%
for col in categorial_cols:
    print('-----------------------------')
    print('Series: ', col)
    print('-----------------------------')
    print(train_data[col].value_counts())
    print('\n')
# Out:
# -----------------------------
# Series:  Item_Identifier
# -----------------------------
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# -----------------------------
# Series:  Item_Fat_Content
# -----------------------------
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# -----------------------------
# Series:  Item_Type
# -----------------------------
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# ...

# %% [markdown]
# # Notes:
#
# > The dataset 8523 contains datapoints (rows) and 12 features (columns).
# > The dataset is for 1559 items in 10 different stores.
# > The present categorical is (object).
# > The target is the _'Item_OutletSales' feature.
# > Some features presents null values and outliers.
# > There are no duplicate rows.
#
# _Item Identifier:
#
# > There are total of 1559 unique items in the dataset.
#
#
# _Item Weight:
#
# > There are missing values in the dataset. These missing values will need to be handled during cleaning process.
#
#
# _Item Fat Content:
#
# > There are two categories of Item_Fat_Content 'Low Fat' and 'Regular'.
# > However there are some items where the Fat content mentiones in a different way such as 'low fat', 'LF' and 'reg' which needs   to be corrected.
# > This feature do not apply to Non-Consumable items, a new category for them can be created.
#
# _Item Visibility:
#
# > Some values are 0%, an item cannot be bought by a consumer if its not visible, this is an outlier.
#
# _Item Type:
#
# > There are 16 different products in item types, the data is not well distributed among all of them.
# > The most common product type is: Fruits and Vegetables and Snack Foods.
#
# _Outlet Identifier:
#
# > There are 10 different outlet/stores.
# > The data seems to be pretty well distributed among all the outlets.
#
# _Outlet Size:
#
# > It has null values.
# > The data is not well distributed among the different sizes.
# > There are three different sizes of outlet 'Small', 'Medium' and 'High'.
#
# _Outlet Location Type:
#
# > There are three different types of outlet location where the outlets are situated - Tier-1, Tier-2 and Tier-3.
#
# _Outlet Type:
#
# > There are four different types of outlet types -
# > Supermarket Type1, Type2, Type3 and Grocery Store.
# > The most common type of outlet is Supermarket Type1 followed by Grocery Store.

# %% [markdown]
# # Getting Numerical columns

# %%
numerical_cols = train_data.select_dtypes(include='number').columns.to_list()

print('Numerical Columns: ', numerical_cols)
# Out:
# Numerical Columns:  ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year', 'Item_Outlet_Sales']

# %% [markdown]
# # Exploring Numerical columns

# %%
for num in numerical_cols:
    print('-----------------------------')
    print('Series: ', num)
    print('-----------------------------')
    print(train_data[num].describe())
    print('\n')
# Out:
# -----------------------------
# Series:  Item_Weight
# -----------------------------
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64
#
#
# -----------------------------
# Series:  Item_Visibility
# -----------------------------
# count    8523.000000
# mean        0.066132
# std         0.051598
# min         0.000000
# 25%         0.026989
# 50%         0.053931
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64
#
#
# -----------------------------
# Series:  Item_MRP
# -----------------------------
# count    8523.000000
# mean      140.992782
# std        62.275067
# min        31.290000
# 25%        93.826500
# 50%       143.012800
# 75%       185.643700
# max       266.888400
# Name: Item_MRP, dtype: float64
#
#
# -----------------------------
# ...

# %% [markdown]
# # Notes:
#
# > The dataset 8523 contains datapoints (rows) and 12 features (columns).
# > The present numerical features is (float, int).
# > The target is the _'Item_OutletSales' feature.
# > Some features presents null values and outliers.
# > There are no duplicate rows.
#
# _Item Weight:
#
# > The mean weight is 12.85, with a standard deviation of 4.64.
# > The minimum weight is 4.55
# > The maximum weight is 21.35
# > And the median is 12.6
#
# _Item Visibility:
#
# > The mean visibility is 0.066, with a standard deviation of 0.052.
# > The minimum visibility is 0.
# > The maximum visibility is 0.328
# > And the median is 0.054
#
# _Item MRP:
#
# > The mean maximum retail price is 140.99, with a standard deviation of 62.28.
# > The minimum price is 31.29.
# > The maximum price is 266.89.
# > And the median is 143.01.
#
# _Outlet Establishment Year:
#
# > This dataset includes the data from outlets established year between 1985 - 2009.
# > The mean establishment year is 1997.83, with a standard deviation of 8.37.
# > The earliest establishment year is 1985.
# > The Latest establishment year is 2009.
# > And the median establishment year is 1999.
#
#
# _Item Outlet Sales:
#
# > The mean sales amount is 2181.29, with a standard deviation of 1706.50.
# > The minimum sales amount is 33.29.
# > The maximum sales amount is 13086.96.
# > And the median sales amount is 1794.33

# %% [markdown]
# # Find Duplicates

# %%
train_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Dataframe Describe

# %%
train_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# # Check for Unique Values

# %%
print(train_data['Item_Fat_Content'].unique())
print(train_data['Item_Type'].unique())
print(train_data['Outlet_Establishment_Year'].sort_values().unique())
print(train_data['Outlet_Location_Type'].unique())
print(train_data['Outlet_Type'].unique())
# Out:
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# [1985 1987 1997 1998 1999 2002 2004 2007 2009]
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
train_data.hist(figsize=(15,12))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# Not much to correlate out of the box
train_data.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
import seaborn as sns
df=train_data.corr()
sns.heatmap(df, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Plot Item_Fat_Content
plt.figure(figsize=(5,5))
sns.countplot(x='Item_Fat_Content', data=train_data)
plt.show()

# %%
# Plot Item_Type
labels = list(train_data['Item_Type'].unique())
chart = sns.countplot(x=train_data['Item_Type'])
chart.set_xticklabels(labels=labels, rotation=90)
# Out:
# [Text(0, 0, 'Dairy'),
#  Text(1, 0, 'Soft Drinks'),
#  Text(2, 0, 'Meat'),
#  Text(3, 0, 'Fruits and Vegetables'),
#  Text(4, 0, 'Household'),
#  Text(5, 0, 'Baking Goods'),
#  Text(6, 0, 'Snack Foods'),
#  Text(7, 0, 'Frozen Foods'),
#  Text(8, 0, 'Breakfast'),
#  Text(9, 0, 'Health and Hygiene'),
#  Text(10, 0, 'Hard Drinks'),
#  Text(11, 0, 'Canned'),
#  Text(12, 0, 'Breads'),
#  Text(13, 0, 'Starchy Foods'),
#  Text(14, 0, 'Others'),
#  Text(15, 0, 'Seafood')]

# %%
# Plot Outlet_Identifier
labels = list(train_data['Outlet_Identifier'].unique())
chart = sns.countplot(x=train_data['Outlet_Identifier'])
chart.set_xticklabels(labels=labels, rotation=90)
# Out:
# [Text(0, 0, 'OUT049'),
#  Text(1, 0, 'OUT018'),
#  Text(2, 0, 'OUT010'),
#  Text(3, 0, 'OUT013'),
#  Text(4, 0, 'OUT027'),
#  Text(5, 0, 'OUT045'),
#  Text(6, 0, 'OUT017'),
#  Text(7, 0, 'OUT046'),
#  Text(8, 0, 'OUT035'),
#  Text(9, 0, 'OUT019')]

# %%
# Plot Outlet_Size
plt.figure(figsize=(5,5))
sns.countplot(x='Outlet_Size', data=train_data)
plt.show()

# %%
# Plot Outlet_Location_Type
plt.figure(figsize=(5,5))
sns.countplot(x='Outlet_Location_Type', data=train_data)
plt.show()

# %%
# Plot Outlet_Establishment_Year
plt.figure(figsize=(6,6))
sns.countplot(x='Outlet_Establishment_Year', data=train_data)
plt.show()

# %%
# Scatter plot of Item_MRP and Item_Outlet_Sales
sns.scatterplot(data=train_data, x='Item_MRP', y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
#
#    There were no major surprise in the dataset.
#
#
# 2. Do you have any concerns about your dataset?
#
#    But, there are few areas of concern that will need to be addressed during data cleaning such as missing values,
#    inconsistencies in the naming of categories and minimum value in the Item_visibility column.
#
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
#
#    For the next phase of analysis while cleaning the following needs to be addressed:
#
#    Handling Missing values in the 'Item_Weight' and 'Outlet_Size' columns.
#
#    Standardizing the naming of categories in the 'Item_Fat_Content' column.
#
#    Addressing the minimum value in the 'Item_Visibility' column.
#
#    Checking for any other inconsistencies or errors in the dataset.
